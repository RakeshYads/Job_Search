# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
# define base URL
base_site = "https://www.naukri.com/peoplesoft-administrator-jobs?k=peoplesoft%20administrator"

# %%
# Submiting a GET request
r = requests.get(base_site)
r.status_code
# Out:
# 200

# %%
r.ok
# Out:
# True

# %%
r.text
html = r.content

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('head')
# Out:
# <head><meta charset="utf-8"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/555cfceadd02ae50.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/fcf15723d0c6750d.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/78d41feaba858687.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/7d9a0cf29dbbd70f.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/fbe735105e31e245.css" rel="stylesheet"/><link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/f7ffa951e455a43c.css" rel="stylesheet"/><link data-pre
# ...

# %%
a = soup.find_all('div', class_ = 'srp-jobtuple-wrapper')

# %%
a
# Out:
# []

# %%
driver = webdriver.Firefox()
driver.get(base_site)

# %%
time.sleep(3)
soup = BeautifulSoup(driver.page_source,"html.parser")

# %%
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/555cfceadd02ae50.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/fcf15723d0c6750d.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/78d41feaba858687.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/7d9a0cf29dbbd70f.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/fbe735105e31e245.css" rel="stylesheet"/>
# ...

# %%
results = soup.find(class_='styles_job-listing-container__OCfZC')

# %%
print(results.findChildren())
# Out:
# [<div class="styles_jlc__main__VdwtF"><div class="srp-jobtuple-wrapper" data-job-id="270524908299"><div class="cust-job-tuple layout-wrapper lay-2 sjw__tuple"><div class="row1"><a class="title" href="https://www.naukri.com/job-listings-peoplesoft-administrator-infosys-limited-bengaluru-5-to-8-years-270524908299" rel="noopener noreferrer" target="_blank" title="Peoplesoft Administrator">Peoplesoft Administrator</a><span class="imagewrap"><img class="logoImage" loading="lazy" src="https://www.naukri.com/hotjobs/images/v3/infosys_nov13.gif"/></span></div><div class="row2"><span class="comp-dtls-wrap"><a class="comp-name mw-25" href="https://www.naukri.com/infosys-jobs-careers-11244" target="_blank" title="Infosys">Infosys</a><a class="rating" href="https://www.ambitionbox.com/reviews/infosys-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box"><span class="ni-job-tuple-icon ni-job-tuple-icon-ot_star star"></span><
# ...

# %%
print(results)
# Out:
# <div class="styles_job-listing-container__OCfZC"><div class="styles_jlc__main__VdwtF"><div class="srp-jobtuple-wrapper" data-job-id="270524908299"><div class="cust-job-tuple layout-wrapper lay-2 sjw__tuple"><div class="row1"><a class="title" href="https://www.naukri.com/job-listings-peoplesoft-administrator-infosys-limited-bengaluru-5-to-8-years-270524908299" rel="noopener noreferrer" target="_blank" title="Peoplesoft Administrator">Peoplesoft Administrator</a><span class="imagewrap"><img class="logoImage" loading="lazy" src="https://www.naukri.com/hotjobs/images/v3/infosys_nov13.gif"/></span></div><div class="row2"><span class="comp-dtls-wrap"><a class="comp-name mw-25" href="https://www.naukri.com/infosys-jobs-careers-11244" target="_blank" title="Infosys">Infosys</a><a class="rating" href="https://www.ambitionbox.com/reviews/infosys-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box"><span class="ni-job-tup
# ...

# %%
job_elems = results.find_all('div',class_='srp-jobtuple-wrapper')
print(job_elems)
# Out:
# [<div class="srp-jobtuple-wrapper" data-job-id="270524908299"><div class="cust-job-tuple layout-wrapper lay-2 sjw__tuple"><div class="row1"><a class="title" href="https://www.naukri.com/job-listings-peoplesoft-administrator-infosys-limited-bengaluru-5-to-8-years-270524908299" rel="noopener noreferrer" target="_blank" title="Peoplesoft Administrator">Peoplesoft Administrator</a><span class="imagewrap"><img class="logoImage" loading="lazy" src="https://www.naukri.com/hotjobs/images/v3/infosys_nov13.gif"/></span></div><div class="row2"><span class="comp-dtls-wrap"><a class="comp-name mw-25" href="https://www.naukri.com/infosys-jobs-careers-11244" target="_blank" title="Infosys">Infosys</a><a class="rating" href="https://www.ambitionbox.com/reviews/infosys-reviews?utm_campaign=srp_ratings&amp;utm_medium=desktop&amp;utm_source=naukri" target="_blank" title="Powered by Ambition Box"><span class="ni-job-tuple-icon ni-job-tuple-icon-ot_star star"></span><span class="main-2">3.8</span><span c
# ...

# %%
def scrape_soup_data(job_elems=None):
    list_data = []
    for job_elem in job_elems:
        #print(job_elem)

        #URL to qpply job
        URL = job_elem.find('a', class_ = 'title').get('href')
#         print(URL)

        title = job_elem.find('a', class_ = 'title')
#         print(title.text)

        company = job_elem.find('a', class_ = lambda x: "comp-name" in x)
        if company is None:
            continue
#         else:
# #             print(company.text)

        experience = job_elem.find('div', class_ = "row3")
        if experience is None:
#             print('Not Disclosed')
            continue
#         else:
#             print(experience.text.split()) 


        keywords_ = job_elem.find('div', class_ = "row5")
        if keywords_ is None:
#             print('Not Disclosed')
            continue
        else:
            lis = []
            list_ = keywords_.find_all("li")
            for li in list_:
                lis.append(li.text)
#             print(lis)

        ratings = job_elem.find('span', class_ = lambda x: "main-2" in x)
        if ratings is None:
#             print('No Review')
            continue
        else:
#             print(ratings.text)
            ratings_no = job_elem.find('a', class_ = lambda x: "review ver-line" in x)
            if ratings_no is None:
                #print('No Details')
                continue
#             else:
# #                 print(ratings_no.get('href'))
# #                 print(ratings_no.text)
        
         #   Appending data to the DataFrame
        list_data.append(['Naukri',URL,title.text,company.text,experience.text.split(),lis,ratings.text,ratings_no.text])
    df=pd.DataFrame(list_data, columns=['SOURCE','URL','TITLE','COMPANY','EXPERIENCE','KEYWORDS','RATINGS', 'NO_OF_RATINGS'])
    return df

# %%
#pagination and defining function
# define base URL
base_site = "https://www.naukri.com/"
def scrape_naukri_func(job_descr=None, location=None, exp=None)->list:
    job_descr_1 = "-".join(job_descr.split())+ "-jobs-" 
    job_descr_2 = "?k=" + "%20".join(job_descr.split())
    driver = webdriver.Firefox()
    job_elems = []
    for page_no in range(1,11):      
        job_descr = job_descr_1 + str(page_no) + job_descr_2
        site = base_site+job_descr
        print(site)
        driver.get(site)
        time.sleep(3)
        soup = BeautifulSoup(driver.page_source,"html.parser")
        results = soup.find(class_='styles_job-listing-container__OCfZC')
        job_elements = results.find_all('div',class_='srp-jobtuple-wrapper')
        job_elems = job_elems + job_elements
        
    driver.close() #closes the browser
    return job_elems
job_data = scrape_naukri_func("data scientist")
print(job_data)
# Out:
# https://www.naukri.com/data-scientist-jobs-1?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-2?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-3?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-4?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-5?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-6?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-7?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-8?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-9?k=data%20scientist
# https://www.naukri.com/data-scientist-jobs-10?k=data%20scientist
# ...

# %%
df = scrape_soup_data(job_data)

# %%
df.head(20)
# Out:
#     SOURCE                                                URL  \
# 0   Naukri  https://www.naukri.com/job-listings-data-scien...
# 1   Naukri  https://www.naukri.com/job-listings-ds-nlp-exp...
# 2   Naukri  https://www.naukri.com/job-listings-data-scien...
# 3   Naukri  https://www.naukri.com/job-listings-data-scien...
# 4   Naukri  https://www.naukri.com/job-listings-data-scien...
# 5   Naukri  https://www.naukri.com/job-listings-data-scien...
# 6   Naukri  https://www.naukri.com/job-listings-data-scien...
# 7   Naukri  https://www.naukri.com/job-listings-data-scien...
# 8   Naukri  https://www.naukri.com/job-listings-data-scien...
# 9   Naukri  https://www.naukri.com/job-listings-lead-data-...
# 10  Naukri  https://www.naukri.com/job-listings-hiring-dat...
# 11  Naukri  https://www.naukri.com/job-listings-data-scien...
# 12  Naukri  https://www.naukri.com/job-listings-generative...
# 13  Naukri  https://www.naukri.com/job-listings-data-scien...
# ...

# %%
base_site = "https://in.linkedin.com/jobs/"
r = requests.get(base_site)

# %%
r.status_code
# Out:
# 200

# %%
r.ok
# Out:
# True
